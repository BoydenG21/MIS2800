# %% [markdown]
# <a href="https://colab.research.google.com/github/BoydenG21/MIS2800/blob/main/HW3_Boyden.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 61.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# %load_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# %sql sqlite:///AdCampaigns2026.db

# %% [markdown]
# Fixed Code blocks

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS Marketing_Brands(
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# %%sql
# INSERT INTO Marketing_Brands(brand_id, brand_name, brand_type, brand_budget)
# VALUES
#   (1, 'Doritos', 'Snacks', 7000000),
#   (2, 'AWS', 'Technology', 15000000),
#   (3, 'Pepsi', 'Beverages', 2000000),
#   (4, 'He_Gets_Us', 'Religious', 1000000),
#   (5, 'Dr_Pepper', 'Beverages', 5000000),
#   (6, 'IBM', 'Technology', 100000),
#   (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
# %%sql
# SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# SELECT brand_name, brand_type FROM Marketing_Brands WHERE brand_budget > 700000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('Google', 'Technology')]

# %%
# %%sql
# -- Instructions: Fix the code to find the brand types that are Religious
# SELECT * FROM Marketing_Brands WHERE brand_type = 'Religious'
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets_Us', 'Religious', 1000000)]

# %%
# %%sql
# SELECT brand_name FROM Marketing_Brands WHERE brand_budget < 1000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('IBM',)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# SELECT brand_name FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages'
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %%
# %%sql
# SELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 100000)]

# %%
# %%sql
# SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# 1. Added "create table if not exist".

# %% [markdown]
# 2. added "INTO Marketing_Brands"

# %% [markdown]
# 3. added * symbol

# %% [markdown]
# 4. added "brand_name, brand_type" then "brand_budget > 700000;"

# %% [markdown]
# 5. added * symbol then "brand_type = 'Religious'"

# %% [markdown]
# 6. added "brand_name" then "brand_budget < 1000000"

# %% [markdown]
# 7. added %%sql

# %% [markdown]
# 8. added "brand_name" then "brand_type = 'Snacks' OR brand_type = 'Beverages'"

# %% [markdown]
# 9. added "brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC"

# %% [markdown]
# 10. added "%%sql
# SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;"
