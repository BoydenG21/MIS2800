# %% [markdown]
# <a href="https://colab.research.google.com/github/BoydenG21/MIS2800/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world")
# Out:
# hello world
